# %% [markdown]
# # Coders of Delhi

# %%
def load_data(filename):
    with open(filename,"r") as f:
        data = json.load(f)
    return data

# %%
data = load_data("data2.json")

# %%
data
# Out:
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]},
#   {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]},
#   {'id': 3, 'name': 'Rahul', 'friends': [1], 'liked_pages': [101, 103]},
#   {'id': 4, 'name': 'Sara', 'friends': [2], 'liked_pages': [104]}],
#  'pages': [{'id': 101, 'name': 'Python Developers'},
#   {'id': 102, 'name': 'Data Science Enthusiasts'},
#   {'id': 103, 'name': 'AI & ML Community'},
#   {'id': 104, 'name': 'Web Dev Hub'}]}

# %%
type(data)
# Out:
# dict

# %%
# Function to display user details and page information
def display_user(data):

    # Print heading
    print("Users and their connections\n")

    # Loop through all users in the dataset
    for user in data['users']:

        # Display user ID, name, friends, and liked pages
        print(
            f"{user['id']} - {user['name']} is friends with: "
            f"{user['friends']} and liked pages are {user['liked_pages']}"
        )

    # Print page information heading
    print("\nPages Information")

    # Loop through all pages
    for page in data['pages']:

        # Display page ID and page name
        print(f"{page['id']} {page['name']}")

# %%
display_user(data)
# Out:
# Users and their connections
#
# 1 - Amit is friends with: [2, 3] and liked pages are [101]
# 2 - Priya is friends with: [1, 4] and liked pages are [102]
# 3 - Rahul is friends with: [1] and liked pages are [101, 103]
# 4 - Sara is friends with: [2] and liked pages are [104]
#
#  Pages Information
# 101 Python Developers
# 102 Data Science Enthusiasts
# 103 AI & ML Community
# 104 Web Dev Hub

# %%
users_data()

# %%
import json

# Function to clean the social network data
def clean_data(data):

    # Remove users whose name is empty or contains only spaces
    data['users'] = [
        user for user in data['users']
        if user['name'].strip()
    ]

    # Remove duplicate friend IDs for each user
    for user in data['users']:
        user['friends'] = list(set(user['friends']))

    # Remove users who have no friends and no liked pages
    data['users'] = [
        user for user in data['users']
        if user['friends'] or user['liked_pages']
    ]

    # Remove duplicate pages based on page ID
    unique_pages = {}

    for page in data['pages']:
        unique_pages[page['id']] = page

    # Convert dictionary values back into a list
    data['pages'] = list(unique_pages.values())

    # Return the cleaned data
    return data


# Load JSON data from file
data = json.load(open("data3.json"))

# Clean the data
data = clean_data(data)

# Save the cleaned data into a new JSON file
json.dump(
    data,
    open("Cleaned_data3.json", "w"),
    indent=4
)

# Display success message
print("Data has been cleaned successfully")
# Out:
# Data has been cleaned successfully

# %%
import json


def load_data(filename):
    """Load JSON data from file."""
    with open(filename, "r") as file:
        return json.load(file)


def clean_data(data):
    """Clean the social network dataset."""

    # Remove users with empty names
    data["users"] = [
        user for user in data["users"]
        if user["name"].strip()
    ]

    # Remove duplicate friend IDs
    for user in data["users"]:
        user["friends"] = list(set(user["friends"]))

    # Remove users with no friends and no liked pages
    data["users"] = [
        user for user in data["users"]
        if user["friends"] or user["liked_pages"]
    ]

    # Remove duplicate pages by page ID
    unique_pages = {}

    for page in data["pages"]:
        unique_pages[page["id"]] = page

    data["pages"] = list(unique_pages.values())

    return data


def save_data(data, filename):
    """Save cleaned data to JSON file."""
    with open(filename, "w") as file:
        json.dump(data, file, indent=4)


def display_users(data):
    """Display user and page information."""

    print("\nUsers and their connections\n")

    for user in data["users"]:
        print(
            f"{user['id']} - {user['name']} is friends with: "
            f"{user['friends']} and liked pages are {user['liked_pages']}"
        )

    print("\nPages Information\n")

    for page in data["pages"]:
        print(f"{page['id']} {page['name']}")


def main():
    input_file = "data3.json"
    output_file = "Cleaned_data3.json"

    data = load_data(input_file)
    cleaned_data = clean_data(data)

    save_data(cleaned_data, output_file)

    print("Data has been cleaned successfully!")

    display_users(cleaned_data)


if __name__ == "__main__":
    main()
# Out:
# Data has been cleaned successfully!
#
# Users and their connections
#
# 1 - Amit is friends with: [2, 3] and liked pages are [101]
# 2 - Priya is friends with: [1, 4] and liked pages are [102]
# 4 - Sara is friends with: [2] and liked pages are [104]
#
# Pages Information
#
# 101 Python Developers
# 102 Data Science Enthusiasts
# 103 AI & ML Community
# 104 Web Development
